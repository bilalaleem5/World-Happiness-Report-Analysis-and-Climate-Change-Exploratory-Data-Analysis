# %%
import pandas as pd 
#importing the pandas library


#loding the 2015 files to be work with

df_2015 = pd.read_csv("2015.csv")



#printing te data of 2015 file
df_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#loding the 2016 files to be work with
df_2016 = pd.read_csv("2016.csv")
#printing the data of 2016 file
df_2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
#loding the 2017 files to be work with
df_2017 = pd.read_csv("2017.csv")
#printig the data of 2017 file
df_2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
#loding the 2018 files to be work with
df_2018 = pd.read_csv("2018.csv")
#printing the data of 2018 file
df_2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
#loding the 2019 files to be work with
df_2019 = pd.read_csv("2019.csv")
#printing the data od 2019 file
df_2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
# part B

# %%
# Filter the DataFrame df_2015 for countries in the year 2015
# with Health (Life Expectancy) between 0.5 and 1
countries_2015 = df_2015[(df_2015["Health (Life Expectancy)"] >= 0.5) & (df_2015["Health (Life Expectancy)"] <= 1)]["Country"]

# printing the resulting countries
countries_2015
# Out:
# 0      Switzerland
# 1          Iceland
# 2          Denmark
# 3           Norway
# 4           Canada
#           ...
# 131      Sri Lanka
# 133       Bulgaria
# 134          Egypt
# 144       Cambodia
# 155          Syria
# Name: Country, Length: 113, dtype: object

# %%
# Filter the DataFrame df_2015 for countries in the year 2016
# with Health (Life Expectancy) between 0.5 and 1
countries_2016 = df_2016[(df_2016["Health (Life Expectancy)"] >= 0.5) & (df_2016["Health (Life Expectancy)"] <= 1)]["Country"]

#printing the data
countries_2016
# Out:
# 0          Denmark
# 1      Switzerland
# 2          Iceland
# 3           Norway
# 4          Finland
#           ...
# 120        Armenia
# 122        Ukraine
# 125        Georgia
# 128       Bulgaria
# 155          Syria
# Name: Country, Length: 106, dtype: object

# %%
# Filter the DataFrame df_2015 for countries in the year 2018
# with Health (Life Expectancy) between 0.5 and 1
countries_2018 = df_2018[(df_2018["Healthy life expectancy"] >= 0.5) & (df_2018["Healthy life expectancy"] <= 1)]["Country or region"]

#printing the data
countries_2018
# Out:
# 0          Finland
# 1           Norway
# 2          Denmark
# 3          Iceland
# 4      Switzerland
#           ...
# 121          Egypt
# 127        Georgia
# 128        Armenia
# 137        Ukraine
# 149          Syria
# Name: Country or region, Length: 107, dtype: object

# %%
# Filter the DataFrame df_2015 for countries in the year 2017
# with Health (Life Expectancy) between 0.5 and 1
countries_2017 = df_2017[(df_2017["Health..Life.Expectancy."] >= 0.5) & (df_2017["Health..Life.Expectancy."] <= 1)]["Country"]

#printing the data
countries_2017
# Out:
# 0           Norway
# 1          Denmark
# 2          Iceland
# 3      Switzerland
# 4          Finland
#           ...
# 119      Sri Lanka
# 120        Armenia
# 124        Georgia
# 131        Ukraine
# 151          Syria
# Name: Country, Length: 103, dtype: object

# %%
# Filter the DataFrame df_2015 for countries in the year 2019
# with Health (Life Expectancy) between 0.5 and 1
countries_2019 = df_2019[(df_2019["Healthy life expectancy"] >= 0.5) & (df_2019["Healthy life expectancy"] <= 1)]["Country or region"]

#printing the dat
countries_2019
# Out:
# 0             Finland
# 1             Denmark
# 4         Netherlands
# 11         Costa Rica
# 14     United Kingdom
#             ...
# 139             India
# 141           Comoros
# 142        Madagascar
# 147          Botswana
# 151            Rwanda
# Name: Country or region, Length: 103, dtype: object

# %% [markdown]
# part C

# %%
#initilization the top 10 values

top_10_2015 = df_2015.head(10)

#printing the data
top_10_2015
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
#initilization the top 10 values
top_10_2016 = df_2016.head(10)


#printing 
top_10_2016
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0      Denmark             Western Europe               1            7.526
# 1  Switzerland             Western Europe               2            7.509
# 2      Iceland             Western Europe               3            7.501
# 3       Norway             Western Europe               4            7.498
# 4      Finland             Western Europe               5            7.413
# 5       Canada              North America               6            7.404
# 6  Netherlands             Western Europe               7            7.339
# 7  New Zealand  Australia and New Zealand               8            7.334
# 8    Australia  Australia and New Zealand               9            7.313
# 9       Sweden             Western Europe              10            7.291
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# ...

# %%
top_10_2017 = df_2017.head(10)
top_10_2017
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
# 5  Netherlands               6            7.377      7.427426     7.326574
# 6       Canada               7            7.316      7.384403     7.247597
# 7  New Zealand               8            7.314      7.379510     7.248490
# 8       Sweden               9            7.284      7.344095     7.223905
# 9    Australia              10            7.284      7.356651     7.211349
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# ...

# %%
#initilization the top 10 values
top_10_2018 = df_2018.head(10)

#prinitng
top_10_2018
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
# 5             6       Netherlands  7.441           1.361           1.488
# 6             7            Canada  7.328           1.330           1.532
# 7             8       New Zealand  7.324           1.268           1.601
# 8             9            Sweden  7.314           1.355           1.501
# 9            10         Australia  7.272           1.340           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# ...

# %%
#initilization the top 10 values

top_10_2019 = df_2019.head(10)


#printing data
top_10_2019
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %% [markdown]
# part D

# %%
# Calculate the mean happiness score for each region in the DataFrame df_2015
mean_happiness_2015 = df_2015.groupby("Region")["Happiness Score"].mean()

#printing
mean_happiness_2015
# Out:
# Region
# Australia and New Zealand          7.285000
# Central and Eastern Europe         5.332931
# Eastern Asia                       5.626167
# Latin America and Caribbean        6.144682
# Middle East and Northern Africa    5.406900
# North America                      7.273000
# Southeastern Asia                  5.317444
# Southern Asia                      4.580857
# Sub-Saharan Africa                 4.202800
# Western Europe                     6.689619
# Name: Happiness Score, dtype: float64

# %%
# Calculate the mean happiness score for each region in the DataFrame df_2016
mean_happiness_2016 = df_2016.groupby("Region")["Happiness Score"].mean()

#printing
mean_happiness_2016
# Out:
# Region
# Australia and New Zealand          7.323500
# Central and Eastern Europe         5.370690
# Eastern Asia                       5.624167
# Latin America and Caribbean        6.101750
# Middle East and Northern Africa    5.386053
# North America                      7.254000
# Southeastern Asia                  5.338889
# Southern Asia                      4.563286
# Sub-Saharan Africa                 4.136421
# Western Europe                     6.685667
# Name: Happiness Score, dtype: float64

# %%
# Calculate the mean happiness score for each region in the DataFrame df_2018
mean_happiness_2018 = df_2018.groupby("Country or region")["Score"].mean()

#printing
mean_happiness_2018
# Out:
# Country or region
# Afghanistan    3.632
# Albania        4.586
# Algeria        5.295
# Angola         3.795
# Argentina      6.388
#                ...
# Venezuela      4.806
# Vietnam        5.103
# Yemen          3.355
# Zambia         4.377
# Zimbabwe       3.692
# Name: Score, Length: 156, dtype: float64

# %%
# Calculate the mean happiness score for each region in the DataFrame df_2019
mean_happiness_2019 = df_2019.groupby("Country or region")["Score"].mean()


#printing
mean_happiness_2019
# Out:
# Country or region
# Afghanistan    3.203
# Albania        4.719
# Algeria        5.211
# Argentina      6.086
# Armenia        4.559
#                ...
# Venezuela      4.707
# Vietnam        5.175
# Yemen          3.380
# Zambia         4.107
# Zimbabwe       3.663
# Name: Score, Length: 156, dtype: float64

# %% [markdown]
# part D

# %%
#importing the metplot library for graphs
import matplotlib.pyplot as plt

#giving dat for box plot
df_2015.boxplot("Happiness Score")

#adding title to grapgh
plt.title("Box Plot of Happiness Score for 2015")



#sowing the required grapgh
plt.show()

# %%
#giving data for box plot
df_2016.boxplot("Happiness Score")

#giving title
plt.title("Box Plot of Happiness Score for 2016")

#showing graph
plt.show()

# %%
#giving data for box plot
df_2017.boxplot("Happiness.Score")

#giving title
plt.title("Box Plot of Happiness Score for 2017")

#showing data
plt.show()

# %%
#giving dat for box plot
df_2018.boxplot("Score")


#giving title
plt.title("Box Plot of Happiness Score for 2018")


#showing data
plt.show()

# %%
#giving dat for box plot
df_2018.boxplot("Score")


#giving title
plt.title("Box Plot of Happiness Score for 2019")

#showing grpah
plt.show()

# %% [markdown]
# Quartiles 2015

# %%
# Define a function to find outliers

def find_outliers(column):

    Q1 = column.quantile(0.25)

    Q3 = column.quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR

    upper_bound = Q3 + 1.5 * IQR

    return column[(column < lower_bound) | (column > upper_bound)]


# Iterate through each DataFrame and find outliers

outliers_dict = {}

for year, df in [(2015, df_2015), (2016, df_2016), (2017, df_2017), (2018, df_2018), (2019, df_2019)]:
    year_outliers = {}

    for column in df.columns:

        if df[column].dtype != object: 

            outliers = find_outliers(df[column])

            if not outliers.empty:

                year_outliers[column] = outliers

                    

    if year_outliers:

        outliers_dict[year] = year_outliers     

            
# Print the outliers for each year and column


for year, year_outliers in outliers_dict.items():

    print(f"Outliers in {year}:")

    for column, outliers in year_outliers.items():

        print(f"From file {year}:")

        print(f"{column}:")

        print(outliers)
# Out:
# Outliers in 2015:
# From file 2015:
# Standard Error:
# 39     0.09811
# 40     0.10895
# 62     0.07832
# 64     0.13693
# 93     0.07896
# 96     0.09438
# 100    0.08742
# 115    0.11068
# 125    0.08096
# 156    0.08658
# Name: Standard Error, dtype: float64
# From file 2015:
# Family:
# 147    0.00000
# 152    0.30285
# 157    0.13995
# Name: Family, dtype: float64
# From file 2015:
# Trust (Government Corruption):
# 0      0.41978
# 2      0.48357
# 3      0.36503
# 5      0.41372
# 7      0.43844
# 8      0.42922
# 16     0.37798
# 19     0.38583
# 23     0.49210
# 27     0.52208
# 71     0.37124
# 90     0.39928
# 129    0.38331
# 153    0.55191
# Name: Trust (Government Corruption), dtype: float64
# From file 2015:
# Generosity:
# 33     0.57630
# 128    0.79588
# Name: Generosity, dtype: float64
# From file 2015:
# Dystopia Residual:
# 13     3.60214
# 71     0.65429
# 131    0.67108
# 153    0.67042
# 155    0.32858
# Name: Dystopia Residual, dtype: float64
# ...

# %%
# Create a scatter plot to visualize the relationship between GDP per Capita and Happiness Score for 2015

plt.scatter(df_2015["Economy (GDP per Capita)"], df_2015 ["Happiness Score"])

# Set labels for the x and y axes
plt.xlabel("Economy (GDP per Capita)")
plt.ylabel("Happiness Score")

#giving title
plt.title("Relationship Between GDP per capita and Happiness Score (2015)")

#ploting
plt.show()

# %%
# Create a scatter plot to visualize the relationship between GDP per Capita and Happiness Score for 2016
plt.scatter(df_2016["Economy (GDP per Capita)"], df_2016 ["Happiness Score"])

# Set labels for the x and y axes
plt.xlabel("Economy (GDP per Capita)")
plt.ylabel("Happiness Score")

# Set a title for the plot
plt.title("Relationship Between GDP per capita and Happiness Score (2016)")


#poting
plt.show()

# %%
# Create a scatter plot to visualize the relationship between GDP per Capita and Happiness Score for 2017
plt.scatter(df_2017["Economy..GDP.per.Capita."], df_2017 ["Happiness.Score"])

# Set labels for the x and y axes
plt.xlabel("Economy (GDP per Capita)")
plt.ylabel("Happiness Score")


# Set a title for the plot

plt.title("Relationship Between GDP per capita and Happiness Score (2017)")

# Display the plot

plt.show()

# %%
# Create a scatter plot to visualize the relationship between GDP per Capita and Happiness Score for 2018

plt.scatter(df_2018["GDP per capita"], df_2018 ["Score"])


# Set labels for the x and y axes

plt.xlabel("Economy (GDP per Capita)")
plt.ylabel("Happiness Score")


# Set a title for the plot

plt.title("Relationship Between GDP per capita and Happiness Score (2018)")

# Display the plot

plt.show()

# %%
# Create a scatter plot to visualize the relationship between GDP per Capita and Happiness Score for 2019

plt.scatter(df_2019["GDP per capita"], df_2019 ["Score"])

# Set labels for the x and y axes

plt.xlabel("Economy (GDP per Capita)")
plt.ylabel("Happiness Score")


# Set a title for the plot

plt.title("Relationship Between GDP per capita and Happiness Score (2019)")

# Display the plot

plt.show()

# %% [markdown]
# part G

# %%
# Define a list of data frames and their corresponding year

data_frames = [(df_2015, 2015), (df_2016, 2016), (df_2017, 2017), (df_2018, 2018), (df_2019, 2019)]



# Initialize an empty DataFrame to store the combined data

combined_data = pd.DataFrame()


# for loop condition
for data, year in data_frames:

    # Rename the 'Country or region' column to 'Country' for consistency

    if 'Country or region' in data:
        
        #data storing

        data = data.rename(columns={'Country or region': 'Country'})


    #if condtions
    if 'Happiness.Score' in data:
        #data store
        data = data.rename(columns={'Happiness.Score': 'Happiness Score'})


    #if condition
    if 'Score' in data:
        #DATA STORE
        data = data.rename(columns={'Score': 'Happiness Score'})

    

    # Select only relevant columns

    columns_to_select = ['Country']
    
    #COLUMNS Appending

    columns_to_select.append('Happiness Score')

    
    # Extract and store the data for the current year

    year_data = data[columns_to_select]
    
    #years data

    year_data['Year'] = year  # Add a 'Year' column
    
    #combining data

    combined_data = pd.concat([combined_data, year_data], ignore_index=True)



# Pivot the DataFrame to have years as columns

happiness_df = combined_data.pivot(index='Country', columns='Year', values='Happiness Score').reset_index()



# Rename columns

happiness_df.columns.name = None  


# Remove the column name

happiness_df.columns = ['Country', '2015', '2016', '2017', '2018', '2019']



# Save to CSV

happiness_df.to_csv("Happiness DataFrame.csv", index=False)

#orinting

happiness_df
# Out:
# C:\Users\bilal\AppData\Local\Temp\ipykernel_8344\82789475.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   year_data['Year'] = year  # Add a 'Year' column
# C:\Users\bilal\AppData\Local\Temp\ipykernel_8344\82789475.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   year_data['Year'] = year  # Add a 'Year' column
# C:\Users\bilal\AppData\Local\Temp\ipykernel_8344\82789475.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# part H

# %%
# Read the combined Happiness DataFrame you constructed in part f

happiness_df = pd.read_csv("Happiness DataFrame.csv")



# Choose two countries
#country !
country1 = 'United States'

#country 2

country2 = 'Canada'



# Select the data for the chosen countries

#country 1
data_country1 = happiness_df[happiness_df['Country'] == country1]

#country 2
data_country2 = happiness_df[happiness_df['Country'] == country2]



# Define the years and corresponding happiness scores

years = ['2015', '2016', '2017', '2018', '2019']

#happiness score of country 1

happiness_scores_country1 = data_country1[years].values.tolist()[0]

#happiness score of country 2

happiness_scores_country2 = data_country2[years].values.tolist()[0]



# Create the line chart

plt.figure(figsize=(10, 6))

#plotlabel

plt.plot(years, happiness_scores_country1, label=country1)

plt.plot(years, happiness_scores_country2, label=country2)



# Add labels and a legend
#x axis
plt.xlabel('Year')

#y axis
plt.ylabel('Happiness Score')

#title of graph
plt.title('Happiness Score Over the Years for {} and {}'.format(country1, country2))

#legend

plt.legend()



# Show the chart

plt.grid(True)


#printing graph
plt.show()

# %%
# Filter the DataFrame to select regions with GDP per Capita less than 0.5 in 2015

regions_low_gdp_2015 = df_2015[df_2015["Economy (GDP per Capita)"] < 0.5]["Region"]

#printing
print(regions_low_gdp_2015.unique()) 

# Count the occurrences of each unique region

regions_count = regions_low_gdp_2015.value_counts()


# Create a bar plot to show the count of regions with low GDP per capita in 2015

plt.figure(figsize = (10, 6))

#region count
regions_count.plot(kind='bar')


# Set the title of the plot

plt.title('cout of regions with low GDP per capita in 2015')

# Label the x and y axes

plt.xlabel('region')
plt.ylabel('count')

# Rotate the x-axis labels for better readability

plt.xticks(rotation = 45)


# Display the plot

plt.show()
# Out:
# ['Central and Eastern Europe' 'Sub-Saharan Africa' 'Southern Asia'
#  'Latin America and Caribbean' 'Southeastern Asia']

# %%
# Filter the DataFrame to select regions with GDP per Capita less than 0.5 in 2016

regions_low_gdp_2016 = df_2016[df_2016["Economy (GDP per Capita)"] < 0.5]["Region"]

#printing
print(regions_low_gdp_2016.unique()) 


# Count the occurrences of each unique region

regions_count = regions_low_gdp_2016.value_counts()


# Create a bar plot to show the count of regions with low GDP per capita in 2015

plt.figure(figsize = (10, 6))
regions_count.plot(kind='bar')


# Set the title of the plot

plt.title('cout of regions with low GDP per capita in 2016')

# Label the x and y axes

plt.xlabel('region')
plt.ylabel('count')

# Rotate the x-axis labels for better readability

plt.xticks(rotation = 45)

# Display the plot

plt.show()
# Out:
# ['Sub-Saharan Africa' 'Central and Eastern Europe' 'Southern Asia'
#  'Southeastern Asia' 'Latin America and Caribbean']

# %%
# Filter the DataFrame to select regions with GDP per Capita less than 0.5 in 2017
regions_low_gdp_2017 = df_2017[df_2017["Economy..GDP.per.Capita."] < 0.5]["Country"]

#printing
print(regions_low_gdp_2017.unique()) 

# Count the occurrences of each unique region

regions_count = regions_low_gdp_2017.value_counts()

# Create a bar plot to show the count of regions with low GDP per capita in 2015


plt.figure(figsize = (10, 6))
regions_count.plot(kind='bar')



# Set the title of the plot

plt.title('cout of regions with low GDP per capita in 2017')

# Label the x and y axes

plt.xlabel('region')
plt.ylabel('count')

# Rotate the x-axis labels for better readability

plt.xticks(rotation = 45)


# Display the plot

plt.show()
# Out:
# ['Somalia' 'Nepal' 'Sierra Leone' 'Mozambique' 'Myanmar' 'Senegal'
#  'Ethiopia' 'Congo (Kinshasa)' 'Mali' 'Uganda' 'Burkina Faso' 'Niger'
#  'Malawi' 'Chad' 'Zimbabwe' 'Afghanistan' 'Benin' 'Madagascar' 'Haiti'
#  'South Sudan' 'Liberia' 'Guinea' 'Togo' 'Rwanda' 'Burundi'
#  'Central African Republic']

# %%
# Filter the DataFrame to select regions with GDP per Capita less than 0.5 in 2018
regions_low_gdp_2018 = df_2018[df_2018["GDP per capita"] < 0.5]["Country or region"]

#printing
print(regions_low_gdp_2018.unique()) 

# Count the occurrences of each unique region

regions_count = regions_low_gdp_2018.value_counts()


# Create a bar plot to show the count of regions with low GDP per capita in 2015

plt.figure(figsize = (10, 6))
regions_count.plot(kind='bar')

# Set the title of the plot

plt.title('cout of regions with low GDP per capita in 2018')

# Label the x and y axes

plt.xlabel('region')
plt.ylabel('count')
# Rotate the x-axis labels for better readability

plt.xticks(rotation = 45)

# Display the plot

plt.show()
# Out:
# ['Tajikistan' 'Somalia' 'Nepal' 'Senegal' 'Sierra Leone' 'Mali'
#  'Burkina Faso' 'Mozambique' 'Kenya' 'Ethiopia' 'Chad' 'Congo (Kinshasa)'
#  'Niger' 'Uganda' 'Benin' 'Togo' 'Guinea' 'Lesotho' 'Madagascar'
#  'Zimbabwe' 'Afghanistan' 'Malawi' 'Haiti' 'Liberia' 'Rwanda' 'Yemen'
#  'Tanzania' 'South Sudan' 'Central African Republic' 'Burundi']

# %%
# Filter the DataFrame to select regions with GDP per Capita less than 0.5 in 2015

regions_low_gdp_2019 = df_2019[df_2019["GDP per capita"] < 0.5]["Country or region"]

#printing
print(regions_low_gdp_2019.unique()) 

# Count the occurrences of each unique region

regions_count = regions_low_gdp_2019.value_counts()


# Create a bar plot to show the count of regions with low GDP per capita in 2015

plt.figure(figsize = (10, 6))
regions_count.plot(kind='bar')

# Set the title of the plot

plt.title('cout of regions with low GDP per capita in 2019')

# Label the x and y axes

plt.xlabel('region')
plt.ylabel('count')

# Rotate the x-axis labels for better readability

plt.xticks(rotation = 45)

# Display the plot

plt.show()
# Out:
# ['Tajikistan' 'Nepal' 'Benin' 'Senegal' 'Somalia' 'Niger' 'Burkina Faso'
#  'Guinea' 'Gambia' 'Mozambique' 'Congo (Kinshasa)' 'Mali' 'Sierra Leone'
#  'Chad' 'Ethiopia' 'Uganda' 'Togo' 'Liberia' 'Comoros' 'Madagascar'
#  'Lesotho' 'Burundi' 'Zimbabwe' 'Haiti' 'Malawi' 'Yemen' 'Rwanda'
#  'Tanzania' 'Afghanistan' 'Central African Republic' 'South Sudan']

# %% [markdown]
# part J

# %%
#part J
# Define a function to calculate the highest correlation for a given year's DataFrame
def find_highest_correlation(data, year):
    
    #igesstt score 
    
    highest_corr = 0.0
    
    #col init
    
    col1, col2 = None, None
    
    
    
    #newdf store to colom data
    
    newdf = data.drop(columns=['Happiness Rank'])
    
    
    
    #numericial columns
    
    num_col = newdf.select_dtypes(include=['float64']).columns

#loop conditions 
    for column1 in num_col:
        
        for column2 in num_col:
        
            if column1 != column2:
        
                correlation = newdf[column1].corr(newdf[column2])
        
                if abs(correlation) > highest_corr:
        
                    high_corr = abs(correlation)
        
                    col1, col2 = column1, column2


#printing
    print(f"For Dataset of {year}, the highest correlation is {high_corr} between columns: {col1} and {col2}")


# Read the combined Happiness DataFrame you constructed in part f

happiness_df = pd.read_csv("Happiness DataFrame.csv")



# Find the highest correlations for both years

find_highest_correlation(df_2015, 2015)

#between 16 and 15

find_highest_correlation(df_2016, 2016)
# Out:
# For Dataset of 2015, the highest correlation is 0.10130111246108815 between columns: Dystopia Residual and Generosity
# For Dataset of 2016, the highest correlation is 0.1330014069822485 between columns: Dystopia Residual and Generosity

# %% [markdown]
# Question 2

# %% [markdown]
# part A

# %%
#imprting the pasndas
import pandas as pd

#reading the csv file
df = pd.read_csv('earth_surface_temperatures.csv')


#finding missing values
missing_values = df.isnull().sum()

#drouping the null values
df.dropna(inplace=True)


#printing the missing valeus
missing_values
# Out:
# Years                    0
# Month                    0
# Country                  0
# Temperature          25753
# Monthly_variation    25753
# Anomaly              25753
# dtype: int64

# %% [markdown]
# part B

# %%
# Check data types of columns
print(data.dtypes)

# Convert data types if necessary
#for years
data['Years'] = pd.to_numeric(data['Years'], errors='coerce')

#for months
data['Month'] = pd.to_numeric(data['Month'], errors='coerce')

#for temperature
data['Temperature'] = pd.to_numeric(data['Temperature'], errors='coerce')

#for monthly variation
data['Monthly_variation'] = pd.to_numeric(data['Monthly_variation'], errors='coerce')


#for anomoly
data['Anomaly'] = pd.to_numeric(data['Anomaly'], errors='coerce')

# Verify data types after conversion
#printing
print(data.dtypes)
# Out:
# Overall rank                      int64
# Country                          object
# Happiness Score                 float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %% [markdown]
# part C

# %%
# Combine Year and Month columns into a Date column

df['Date'] = pd.to_datetime(df['Years'].astype(str) + '-' + df['Month'].astype(str), format = '%Y-%m')


# Drop the Year and Month columns

df.drop(columns=['Years', 'Month'], inplace=True)


#printing the dataframe
df
# Out:
#             Country  Temperature  Monthly_variation  Anomaly       Date
# 0       Afghanistan       19.573             -0.297    2.037 1848-05-01
# 1       Afghanistan       23.894             -0.796    2.136 1848-06-01
# 2       Afghanistan       26.507             -0.113    1.937 1848-07-01
# 3       Afghanistan       24.498             -0.462    1.937 1848-08-01
# 4       Afghanistan       19.068             -1.272    1.865 1848-09-01
# ...             ...          ...                ...      ...        ...
# 534566     Zimbabwe       19.621              1.401    0.466 2020-08-01
# 534567     Zimbabwe       22.638              1.008    0.246 2020-09-01
# 534568     Zimbabwe       24.588              0.458    0.294 2020-10-01
# 534569     Zimbabwe       25.934              1.724    1.035 2020-11-01
# 534570     Zimbabwe       23.595             -0.025    0.574 2020-12-01
#
# [508818 rows x 5 columns]

# %% [markdown]
# part D

# %%
#importing seaborn
import seaborn as sns

#improting ploting library 
import matplotlib.pyplot as plt



#boxplot for the temperature 
sns.boxplot(x = df['Temperature'])

#printing graph
plt.show()

# %% [markdown]
# part E

# %%
# Reset the index to convert the index names to columns temporarily

df_reset = df.reset_index()


# Calculate summary statistics for the specified columns

summary_stats = df_reset[['Temperature', 'Monthly_variation', 'Anomaly']].describe()

# Print the summary statistics

print(summary_stats)


# Calculate and print the median for the specified columns

median = df_reset[['Temperature', 'Monthly_variation', 'Anomaly']].median()

#printing  median 
print(median)
# Out:
#          Temperature  Monthly_variation        Anomaly
# count  508818.000000      508818.000000  508818.000000
# mean       17.059014          -0.075495       0.888305
# std        11.201763           1.231296       1.069699
# min       -40.349000         -10.566000       0.037000
# 25%         9.776250          -0.663000       0.293000
# 50%        20.705000          -0.076000       0.494000
# 75%        25.911000           0.552000       1.004000
# max        39.384000          11.817000      12.203000
# Temperature          20.705
# Monthly_variation    -0.076
# Anomaly               0.494
# dtype: float64

# %% [markdown]
# part F

# %%
# Calculate average temperature by country

average_temperature_by_country = df.groupby('Country')['Temperature'].mean()


# Display the resulting Series showing the average temperature for each country

average_temperature_by_country
# Out:
# Country
# Afghanistan       14.079393
# Albania           12.756664
# Algeria           23.243877
# American Samoa    26.772271
# Andorra           11.136555
#                     ...
# Virgin Islands    26.428190
# Western Sahara    23.869300
# Yemen             26.201893
# Zambia            21.411139
# Zimbabwe          21.187783
# Name: Temperature, Length: 233, dtype: float64

# %%
# Assuming you have a DataFrame 'df' with the relevant data

# Group by 'Country' and calculate the mean temperature
average_temperature_by_country = df.groupby('Country')['Temperature'].mean()


# Create a bar graph to visualize the average temperatures by country

average_temperature_by_country.plot(kind = 'bar', figsize=(10,6))

# Set the title of the plot

plt.title('Average Temperature by country')

# Label the x and y axes

plt.xlabel('Country')
plt.ylabel('Average Temperature (c)')

# Rotate x-axis labels for better readability

plt.xticks(rotation = 90) 
# Display the plot



plt.show()

# %% [markdown]
# Part G

# %%
# Group data by year and calculate the annual mean temperature

annual_mean_temperature = df.groupby(df['Date'].dt.year)['Temperature'].mean()

# Create a line plot to visualize the temperature trend


plt.figure(figsize = (12,6))
plt.plot(annual_mean_temperature.index, annual_mean_temperature.values)

# Set the title of the plot

plt.title('Global Temperature Trend Over the Years')

# Label the x and y axes

plt.xlabel('Year')
plt.ylabel('Temperature (c)')


# Display a grid for better visualization

plt.grid(True)


# Display the plot

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# part H

# %%
# Find the months with the highest temperatures for each country

highest_temperature = df.groupby(['Country',df['Date'].dt.month])['Temperature'].max()

# Find the months with the lowest temperatures for each country

lowest_temperature = df.groupby(['Country', df['Date'].dt.month])['Temperature'].min()

# Calculate the seasonal patterns (temperature range) for each country


seasonal_patterns = highest_temperature - lowest_temperature

# Display the resulting Series showing the seasonal patterns for each country

seasonal_patterns
# Out:
# Country      Date
# Afghanistan  1        9.011
#              2       11.519
#              3        9.586
#              4        7.290
#              5        7.504
#                       ...
# Zimbabwe     8        5.745
#              9        5.506
#              10       4.701
#              11       4.470
#              12       4.712
# Name: Temperature, Length: 2796, dtype: float64

# %% [markdown]
# part I

# %%
# Find months with consistently high or low anomalies

monthly_anomaly_stats = df.groupby(df['Date'].dt.month)['Anomaly'].describe()


# Display the summary statistics for the 'Anomaly' column by month

monthly_anomaly_stats
# Out:
#         count      mean       std    min    25%    50%    75%     max
# Date
# 1     42421.0  1.055295  1.365037  0.063  0.313  0.554  1.172  11.234
# 2     42456.0  1.037342  1.329701  0.039  0.305  0.543  1.169  12.184
# 3     42472.0  0.906155  1.055742  0.048  0.293  0.504  1.039   9.929
# 4     42439.0  0.864382  0.971719  0.037  0.292  0.485  1.005   9.347
# 5     42460.0  0.827216  0.961103  0.058  0.291  0.479  0.951   9.401
# 6     42305.0  0.854485  1.030313  0.062  0.298  0.486  0.953  10.664
# 7     42391.0  0.825886  0.932905  0.043  0.293  0.475  0.959  10.053
# 8     42371.0  0.800160  0.899261  0.062  0.283  0.467  0.920  10.081
# 9     42342.0  0.785415  0.878990  0.048  0.279  0.452  0.889   6.966
# 10    42331.0  0.815619  0.985137  0.056  0.276  0.454  0.913  10.869
# 11    42424.0  0.922476  1.164930  0.060  0.294  0.500  1.028  12.203
# 12    42406.0  0.964586  1.088235  0.057  0.313  0.540  1.139  10.559

# %% [markdown]
# part J

# %%
# Define the five countries for comparison

countries_to_compare = ['Pakistan', 'Iran', 'India', 'China', 'Bangladesh']

# Filter the data for the selected countries

selected_countries_data = df[df['Country'].isin(countries_to_compare)]

# Create a line plot to compare temperature trends for the selected countries

plt.figure(figsize=(12,6))

for country in countries_to_compare:

    country_data = selected_countries_data[selected_countries_data['Country'] == country]

    plt.plot(country_data['Date'], country_data['Temperature'],label = country)

#Set the title of the plot
   
plt.title('Temperature Trend for Five Countries') 

# Label the x and y axes

plt.xlabel('Date')
plt.ylabel('Temperature')

# Display a legend to identify each country's data

plt.legend()

# Display a grid for better visualization

plt.grid(True)

# Show the plot

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# part K

# %%
# Calculate correlation coefficients

correlation_temp_monthly_var = df['Temperature'].corr(df['Monthly_variation'])


# Calculate correlation coefficients

correlation_temp_monthly_var = df['Temperature'].corr(df['Anomaly'])

# Create scatterplots

plt.figure(figsize = (12 ,6))

#subpints
plt.subplot(1, 2, 1)

#scatteing
plt.scatter(df['Temperature'], df['Monthly_variation'], s=20, alpha=0.5, label='Monthly Variation', color='purple')


#title for graph
plt.title(f'Correlation: {correlation_temp_monthly_var: .2f}')


#x axis label
plt.xlabel('Temperature (c)')


# y label title
plt.ylabel('Monthly Variation')

#subloints
plt.subplot(1, 2, 2)


#scattering
plt.scatter(df['Temperature'], df['Anomaly'], s=20, alpha=0.5, label='Monthly Variation', color='red')


#titile 
plt.title(f'Correlation: {correlation_temp_monthly_var:.2f}')


# 2 grapgh x axis label
plt.xlabel('Tempreature')

# y axis title
plt.ylabel('Anomaly')


#layout format
plt.tight_layout()


#pringt graph
plt.show()
